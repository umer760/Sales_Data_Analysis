# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import glob
#%pip install mplcursors

# %% [markdown]
# MERGING MONTH'S SALES INTO SINGLE FILE

# %%
csv_files = glob.glob("C:\\Users\\Umer\\OneDrive\\Documents\\data_analysis.py\\project2.py\\Sales_data_2019"+"/*.csv") 
dataframe=[]
for file in csv_files:
    df=pd.read_csv(file)
    dataframe.append(df)
combine=pd.concat(dataframe,ignore_index=True)
combine.to_csv("Sales_Data.csv",index=True)

# %% [markdown]
# ## DATA EXPLORATION AND CLEANING

# %%
dataset=combine.copy()
dataset
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
dataset=pd.DataFrame(dataset)
dataset.dropna(inplace=True)
dataset
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
dataset=dataset.convert_dtypes()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185686 entries, 0 to 186849
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185686 non-null  int64
#  1   Product           185686 non-null  string
#  2   Quantity Ordered  185686 non-null  int64
#  3   Price Each        185686 non-null  float64
#  4   Order Date        185686 non-null  object
#  5   Purchase Address  185686 non-null  string
#  6   Month             185686 non-null  Int64
#  7   Sales             185686 non-null  float64
#  8   Month_Name        185686 non-null  object
#  9   City              185686 non-null  object
#  10  Order_Time        185686 non-null  object
#  11  Time_Zone         185686 non-null  object
# dtypes: Int64(1), float64(2), int64(2), object(5), string(2)
# memory usage: 18.6+ MB

# %%
dataset["Month"]=dataset["Order Date"].str[0:2]
dataset
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address Month
# ...

# %%
dataset["Month"] = pd.to_numeric(dataset["Month"], errors='coerce')
r=dataset["Month"].isna().sum()
dataset.dropna(inplace=True)

# %%
dataset["Month"].isna().sum()
# Out:
# np.int64(0)

# %%
dataset["Price Each"]=dataset["Price Each"].astype(float)

# %%
dataset["Quantity Ordered"]=dataset["Quantity Ordered"].astype(int)

# %%
duplicates=dataset.duplicated()
dataset.drop_duplicates(inplace=True)
dataset
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month
# ...

# %%
dataset["Sales"]=dataset["Price Each"] * dataset["Quantity Ordered"]
dataset
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month   Sales
# ...

# %%
def monthname(x):
    if x==1:
     return "Janauary"
    elif x==2:
       return "Feburary"
    elif x==3:
       return "March"
    elif x==4:
       return "April"
    elif x==5:
       return "May"
    elif x==6:
       return "June"
    elif x==7:
       return "July"
    elif x==8:
       return "August"
    elif x==9:
       return "September"
    elif x==10:
       return "October"
    elif x==11:
       return "November"
    else:
       return "December"

# %% [markdown]
# ## MONTHLY SALES

# %%
dataset["Month_Name"]=dataset["Month"].apply(monthname)

# %%
Month_sales=dataset.groupby("Month_Name")["Sales"].sum().reset_index(name="Month_Sales")
Month_sales=Month_sales.sort_values(by="Month_Sales",ascending=False)
Month_sales
# Out:
#    Month_Name  Month_Sales
# 2    December   4608295.70
# 10    October   3734777.86
# 0       April   3389217.98
# 9    November   3197875.05
# 8         May   3150616.23
# 7       March   2804973.35
# 5        July   2646461.32
# 6        June   2576280.15
# 1      August   2241083.37
# 3    Feburary   2200078.08
# 11  September   2094465.69
# 4    Janauary   1821413.16

# %%
Month_Graph=Month_sales.plot.bar(x="Month_Name",y="Month_Sales",color="green")
def million(x,pos):
    return f"{x/1000000:.1f}M"
Month_Graph.yaxis.set_major_formatter(ticker.FuncFormatter(million))
for p in Month_Graph.patches:
    Month_Graph.annotate(f'{p.get_height()/1000:,.0f}K', (p.get_x() + p.get_width() / 2.,p.get_height()), ha='center', va='bottom')
plt.show()

# %% [markdown]
# ###BEST SALE MONTH IS DECEMBER
# DECEMBER SALE=4608295.70

# %%
dataset["City"]=dataset["Purchase Address"].str.split(",").str[1]
dataset
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %% [markdown]
# ## CITY SALES

# %%
dataset["City"]=dataset["City"].astype(str)

# %%
City_Sales=dataset.groupby("City")["Sales"].sum().reset_index(name="City_Sale")
City_Sales=City_Sales.sort_values(by="City_Sale",ascending=False)
City_Sales
# Out:
#              City   City_Sale
# 7   San Francisco  8254743.55
# 4     Los Angeles  5448304.28
# 5   New York City  4661867.14
# 2          Boston  3658627.65
# 0         Atlanta  2794199.07
# 3          Dallas  2765373.96
# 8         Seattle  2745046.02
# 6        Portland  2319331.94
# 1          Austin  1818044.33

# %% [markdown]
# TOP_PRODUCT_SAILING CITY IS San Francisco
# San Francisco sale =$8254743.55

# %%
City_Graph=City_Sales.plot.bar(x="City",y="City_Sale",color="green")
def million(x,pos):
    return f"{x/1000000:.1f}M"
City_Graph.yaxis.set_major_formatter(ticker.FuncFormatter(million))
for p in City_Graph.patches:
    City_Graph.annotate(f'{p.get_height()/1000:,.0f}K', (p.get_x() + p.get_width() / 2.,p.get_height()), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## BEST TIME FOR SALE

# %% [markdown]
# ###What time should we display advertisemens to maximize the likelihood of customer’s buying product?

# %%
dataset["Order_Time"]=dataset["Order Date"].str[9:]
dataset
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
dataset["Order_Time"]=dataset["Order_Time"].astype(str)
dataset["Order Date"]=dataset["Order Date"].astype(str)

# %%
def timezone(x):
    if  "00:00"<=x<="05:00":
        return "Mid_Night"
    elif "05:01"<=x<="12:00":
        return "Morning"
    elif "12:01"<=x<="15:00" :
        return "Afternoon" 
    else:
        return "Evening"
dataset["Time_Zone"]=dataset["Order_Time"].apply(timezone)
dataset
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
Best_selling_Time=dataset.groupby("Time_Zone")["Order ID"].nunique().reset_index(name="Customer")
Best_selling_Time
# Out:
#    Time_Zone  Customer
# 0  Afternoon     34252
# 1    Evening     90874
# 2  Mid_Night      8843
# 3    Morning     44468

# %%
selling_Time_Graph=Best_selling_Time.plot.bar(x="Time_Zone",y="Customer",color="green")
for p in selling_Time_Graph.patches:
    selling_Time_Graph.annotate(f'{p.get_height()/1000:,.0f}K', (p.get_x() + p.get_width() / 2.,p.get_height()), ha='center', va='bottom')
plt.show()

# %% [markdown]
#  BEST TIME FOR ADVERTISEMENT IS EVENING (3:01 PM TO 12:00PM)

# %% [markdown]
# ## What products are most often sold together?

# %%
dataset["Order ID"]=dataset["Order ID"].astype(int)

# %%
Product=dataset.groupby("Order ID").agg({"Product":",".join})
Top_Ptoduct=Product.loc[Product["Product"].str.contains(",")].value_counts().reset_index(name="Best_Sold_Together")
print("Total rows: ",len(Top_Ptoduct))
Top_Ptoduct
# Out:
# Total rows:  350
#                                                Product  Best_Sold_Together
# 0                      iPhone,Lightning Charging Cable                 886
# 1                    Google Phone,USB-C Charging Cable                 857
# 2                              iPhone,Wired Headphones                 361
# 3                 Vareebadd Phone,USB-C Charging Cable                 312
# 4                        Google Phone,Wired Headphones                 303
# ..                                                 ...                 ...
# 345             27in 4K Gaming Monitor,Vareebadd Phone                   1
# 346                20in Monitor,34in Ultrawide Monitor                   1
# 347  iPhone,Lightning Charging Cable,Wired Headphon...                   1
# 348  iPhone,Lightning Charging Cable,Wired Headphon...                   1
# 349   iPhone,Wired Headphones,Lightning Charging Cable                   1
#
# [350 rows x 2 columns]

# %% [markdown]
# Iphone and lightning are the two product which usually customer bought toghether.

# %%
best_product=Top_Ptoduct.head(15)
TOP_Product_Graph=best_product.plot.barh(x="Product",y="Best_Sold_Together",color="green")
plt.bar_label(TOP_Product_Graph.containers[0])
plt.ylabel("TOP 15 Products")
plt.show()

# %% [markdown]
# ## - Which product sold the most? Why do you think it sold the most?

# %%
Quantity_Sold=dataset.groupby(["Product","Price Each"])["Quantity Ordered"].sum().reset_index(name="Quantity_Sold").sort_values(by="Quantity_Sold",ascending=False)
Quantity_Sold
# Out:
#                        Product  Price Each  Quantity_Sold
# 5       AAA Batteries (4-pack)        2.99          30986
# 4        AA Batteries (4-pack)        3.84          27615
# 15        USB-C Charging Cable       11.95          23931
# 12    Lightning Charging Cable       14.95          23169
# 17            Wired Headphones       11.99          20524
# 6     Apple Airpods Headphones      150.00          15637
# 7   Bose SoundSport Headphones       99.99          13430
# 2             27in FHD Monitor      149.99           7541
# 18                      iPhone      700.00           6847
# 1       27in 4K Gaming Monitor      389.99           6239
# 3       34in Ultrawide Monitor      379.99           6192
# 9                 Google Phone      600.00           5529
# 8                Flatscreen TV      300.00           4813
# 13          Macbook Pro Laptop     1700.00           4725
# 14             ThinkPad Laptop      999.99           4128
# ...

# %% [markdown]
# The most sold product is AAA Batteries (4-pack) =30986 quantity sold
# its because it's buying cost is cheaper than the other product .
